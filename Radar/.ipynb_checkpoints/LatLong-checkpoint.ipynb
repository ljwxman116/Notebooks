# %%
# %matplotlib inline
import matplotlib
import pyart
import numpy as np
import matplotlib.pyplot as plt
matplotlib.rcParams['figure.figsize'] = [14.0, 11.0]

# %%
radar = pyart.io.read('KDVN.gz')
display = pyart.graph.RadarMapDisplay(radar)

# %%
display.plot_ppi_map('reflectivity', vmin=0, vmax=65,
                     min_lon=-90.60, max_lon=-88.82, min_lat=41.50, max_lat=42.2,
                     lon_lines=None, projection='lcc',
                     lat_lines=None, resolution='i', cmap='pyart_Carbone17')
display.basemap.drawcounties()
'''
# plot range rings at 10, 20, 30 and 40km
display.plot_range_ring(10., line_style='k-')
display.plot_range_ring(20., line_style='k--')
display.plot_range_ring(30., line_style='k-')
display.plot_range_ring(40., line_style='k--')

# plots cross hairs
display.plot_line_xy(np.array([-40000.0, 40000.0]), np.array([0.0, 0.0]),
                     line_style='k-')
display.plot_line_xy(np.array([0.0, 0.0]), np.array([-20000.0, 200000.0]),
                     line_style='k-')

# Indicate the radar location with a point
display.plot_point(radar.longitude['data'][0], radar.latitude['data'][0])
'''
plt.show()

# %%
display.plot_ppi_map('velocity', sweep=1, vmin=-65, vmax=65,
                     min_lon=-90.60, max_lon=-88.82, min_lat=41.50, max_lat=42.2,
                     lon_lines=None, projection='lcc',
                     lat_lines=None, resolution='i', cmap='pyart_NWSVel')
display.basemap.drawcounties()
'''
# plot range rings at 10, 20, 30 and 40km
display.plot_range_ring(10., line_style='k-')
display.plot_range_ring(20., line_style='k--')
display.plot_range_ring(30., line_style='k-')
display.plot_range_ring(40., line_style='k--')

# plots cross hairs
display.plot_line_xy(np.array([-40000.0, 40000.0]), np.array([0.0, 0.0]),
                     line_style='k-')
display.plot_line_xy(np.array([0.0, 0.0]), np.array([-20000.0, 200000.0]),
                     line_style='k-')

# Indicate the radar location with a point
display.plot_point(radar.longitude['data'][0], radar.latitude['data'][0])
'''
plt.show()

# %%
display.plot_ppi_map('cross_correlation_ratio', vmin=.2, vmax=1,
                     min_lon=-90.60, max_lon=-88.82, min_lat=41.50, max_lat=42.2,
                     lon_lines=None, projection='lcc',
                     lat_lines=None, resolution='c')
display.basemap.drawcounties()
'''
# plot range rings at 10, 20, 30 and 40km
display.plot_range_ring(10., line_style='k-')
display.plot_range_ring(20., line_style='k--')
display.plot_range_ring(30., line_style='k-')
display.plot_range_ring(40., line_style='k--')

# plots cross hairs
display.plot_line_xy(np.array([-40000.0, 40000.0]), np.array([0.0, 0.0]),
                     line_style='k-')
display.plot_line_xy(np.array([0.0, 0.0]), np.array([-20000.0, 200000.0]),
                     line_style='k-')
'''
# Indicate the radar location with a point
#display.plot_point(-89.701996, 41.787697, color='green')
plt.show()

# %%
radar.info('compact')
# Out:
# altitude: <ndarray of type: float64 and shape: (1L,)>
# altitude_agl: None
# antenna_transition: None
# azimuth: <ndarray of type: float64 and shape: (9720L,)>
# elevation: <ndarray of type: float32 and shape: (9720L,)>
# fields:
# 	differential_phase: <ndarray of type: float32 and shape: (9720L, 1832L)>
# 	cross_correlation_ratio: <ndarray of type: float32 and shape: (9720L, 1832L)>
# 	spectrum_width: <ndarray of type: float32 and shape: (9720L, 1832L)>
# 	reflectivity: <ndarray of type: float32 and shape: (9720L, 1832L)>
# 	differential_reflectivity: <ndarray of type: float32 and shape: (9720L, 1832L)>
# 	velocity: <ndarray of type: float32 and shape: (9720L, 1832L)>
# fixed_angle: <ndarray of type: float32 and shape: (19L,)>
# instrument_parameters:
# 	unambiguous_range: <ndarray of type: float32 and shape: (9720L,)>
# 	nyquist_velocity: <ndarray of type: float32 and shape: (9720L,)>
# latitude: <ndarray of type: float64 and shape: (1L,)>
# longitude: <ndarray of type: float64 and shape: (1L,)>
# nsweeps: 19
# ngates: 1832
# nrays: 9720
# radar_calibration: None
# range: <ndarray of type: int32 and shape: (1832L,)>
# scan_rate: None
# scan_type: ppi
# sweep_end_ray_index: <ndarray of type: int32 and shape: (19L,)>
# sweep_mode: <ndarray of type: |S20 and shape: (19L,)>
# sweep_number: <ndarray of type: int32 and shape: (19L,)>
# sweep_start_ray_index: <ndarray of type: int32 and shape: (19L,)>
# target_scan_rate: None
# time: <ndarray of type: float64 and shape: (9720L,)>
# metadata:
# 	comment:
# 	title:
# 	Conventions: CF/Radial instrument_parameters
# 	source:
# 	version: 1.3
# 	references:
# 	instrument_name:
# 	original_container: NEXRAD Level II
# 	institution:
# 	history:
