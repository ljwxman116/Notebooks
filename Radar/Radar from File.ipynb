# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = [12.0, 9.0]

# %%
import pyart

# %%
radar = pyart.io.read('KARX_20151101_040450.bz2')
radar.info('compact')
# Out:
# altitude: <ndarray of type: float64 and shape: (1L,)>
# altitude_agl: None
# antenna_transition: None
# azimuth: <ndarray of type: float64 and shape: (6960L,)>
# elevation: <ndarray of type: float32 and shape: (6960L,)>
# fields:
# 	differential_phase: <ndarray of type: float32 and shape: (6960L, 1832L)>
# 	cross_correlation_ratio: <ndarray of type: float32 and shape: (6960L, 1832L)>
# 	spectrum_width: <ndarray of type: float32 and shape: (6960L, 1832L)>
# 	reflectivity: <ndarray of type: float32 and shape: (6960L, 1832L)>
# 	differential_reflectivity: <ndarray of type: float32 and shape: (6960L, 1832L)>
# 	velocity: <ndarray of type: float32 and shape: (6960L, 1832L)>
# fixed_angle: <ndarray of type: float32 and shape: (12L,)>
# instrument_parameters:
# 	unambiguous_range: <ndarray of type: float32 and shape: (6960L,)>
# 	nyquist_velocity: <ndarray of type: float32 and shape: (6960L,)>
# latitude: <ndarray of type: float64 and shape: (1L,)>
# ...

# %%
#display = pyart.graph.RadarMapDisplay(radar)
display.plot_ppi_map(
    'cross_correlation_ratio', vmin=-10, vmax=10, cmap='pyart_Carbone42',
    resolution='c', embelish=False)
#display.plot(
#     'reflectivity', vmin=5, vmax=80, cmap='pyart_Carbone42')
display.basemap.drawcounties()
#display.set_limits(ylim=(0, 200), xlim=(0, 200))
