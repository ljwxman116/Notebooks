# %%
# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.figsize'] = [12.0, 9.0]

# %%
import pyart

# %%
radar = pyart.io.read('KLOT20150409_235952_V06.gz')

# %%
display = pyart.graph.RadarDisplay(radar)

# %%
radar.info('compact')
# Out:
# altitude: <ndarray of type: float64 and shape: (1L,)>
# altitude_agl: None
# antenna_transition: None
# azimuth: <ndarray of type: float64 and shape: (9360L,)>
# elevation: <ndarray of type: float32 and shape: (9360L,)>
# fields:
# 	differential_phase: <ndarray of type: float32 and shape: (9360L, 1832L)>
# 	cross_correlation_ratio: <ndarray of type: float32 and shape: (9360L, 1832L)>
# 	spectrum_width: <ndarray of type: float32 and shape: (9360L, 1832L)>
# 	reflectivity: <ndarray of type: float32 and shape: (9360L, 1832L)>
# 	differential_reflectivity: <ndarray of type: float32 and shape: (9360L, 1832L)>
# 	velocity: <ndarray of type: float32 and shape: (9360L, 1832L)>
# fixed_angle: <ndarray of type: float32 and shape: (18L,)>
# instrument_parameters:
# 	unambiguous_range: <ndarray of type: float32 and shape: (9360L,)>
# 	nyquist_velocity: <ndarray of type: float32 and shape: (9360L,)>
# latitude: <ndarray of type: float64 and shape: (1L,)>
# longitude: <ndarray of type: float64 and shape: (1L,)>
# nsweeps: 18
# ngates: 1832
# nrays: 9360
# radar_calibration: None
# range: <ndarray of type: int32 and shape: (1832L,)>
# scan_rate: None
# scan_type: ppi
# sweep_end_ray_index: <ndarray of type: int32 and shape: (18L,)>
# sweep_mode: <ndarray of type: |S20 and shape: (18L,)>
# sweep_number: <ndarray of type: int32 and shape: (18L,)>
# sweep_start_ray_index: <ndarray of type: int32 and shape: (18L,)>
# target_scan_rate: None
# time: <ndarray of type: float64 and shape: (9360L,)>
# metadata:
# 	comment:
# 	title:
# 	Conventions: CF/Radial instrument_parameters
# 	source:
# 	version: 1.3
# 	references:
# 	instrument_name:
# 	original_container: NEXRAD Level II
# 	institution:
# 	history:

# %%
display.plot('velocity', sweep=1, vmin=-60, vmax=60, cmap='pyart_NWSVel')
display.set_limits(ylim=(30, 100), xlim=(-100, -50))
