# %%
# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.figsize'] = [12.0, 9.0]
import pyart

# %%
radar = pyart.io.read('KLOT20150410_001552_V06.gz')

# %%
radar.info('compact')

# %%
display = pyart.graph.RadarDisplay(radar)

# %%
display.plot('reflectivity', sweep=1, vmin=0, vmax=70, cmap='pyart_Carbone17')
display.set_limits(ylim=(30, 100), xlim=(-100, -50))

# %%
display.plot('velocity', sweep=1, vmin=-60, vmax=60, cmap='pyart_NWSVel') #-60,60
display.set_limits(ylim=(30, 100), xlim=(-100, -50))

# %%
display.plot('cross_correlation_ratio', vmin=.2, vmax=1.05)#-.2,1.2
display.set_limits(ylim=(30, 100), xlim=(-100, -50))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c5ec8b0a0c0b> in <module>()
# ----> 1 display.plot('cross_correlation_ratio', vmin=.2, vmax=1.05)#-.2,1.2
#       2 display.set_limits(ylim=(30, 100), xlim=(-100, -50))
#
# NameError: name 'display' is not defined
